# %% [markdown]
# <a href="https://colab.research.google.com/github/AbdulHaseeb790/AbdulHaseeb790/blob/main/CIFAR10_CNN_Image_Classifier.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # . Imports

# %%
import tensorflow as tf
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Conv2D,MaxPooling2D,Dense,Flatten,Dropout

# %% [markdown]
# Load Dataset

# %%
from tensorflow.keras.datasets import cifar10
(x_train,y_train),(x_test,y_test)=cifar10.load_data()

# %% [markdown]
#  Visualize Images

# %%
print(x_train.shape)
print(y_train.shape)
# Out:
# (50000, 32, 32, 3)
# (50000, 1)

# %%
print(y_train[0])
# Out:
# [6]

# %% [markdown]
# Normalize Data

# %%
x_train=x_train/255.0
x_test=x_test/255.0

# %% [markdown]
# Build CNN

# %%
model=Sequential()

# %%
model.add(Conv2D(33,(3,3),activation='relu',input_shape=(32,32,3)))
# Out:
# /usr/local/lib/python3.12/dist-packages/keras/src/layers/convolutional/base_conv.py:113: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)

# %%
model.add(MaxPooling2D(2,2))

# %%
model.add(Flatten())

# %%
model.add(Dense(64,activation='relu'))

# %%
model.add(Dense(10,activation='softmax'))

# %% [markdown]
# Compile Model

# %%
model.compile(optimizer='adam',loss='sparse_categorical_crossentropy',metrics=['accuracy'])

# %% [markdown]
# Train Model

# %%
model.fit(x_train,y_train,epochs=10)
# Out:
# Epoch 1/10
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 24s 15ms/step - accuracy: 0.4684 - loss: 1.4886
# Epoch 2/10
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 23s 15ms/step - accuracy: 0.5841 - loss: 1.1912
# Epoch 3/10
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 23s 15ms/step - accuracy: 0.6281 - loss: 1.0687
# Epoch 4/10
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 23s 15ms/step - accuracy: 0.6590 - loss: 0.9843
# Epoch 5/10
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 23s 15ms/step - accuracy: 0.6775 - loss: 0.9305
# Epoch 6/10
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 40s 14ms/step - accuracy: 0.6939 - loss: 0.8858
# Epoch 7/10
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 40s 14ms/step - accuracy: 0.7091 - loss: 0.8369
# Epoch 8/10
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 22s 14ms/step - accuracy: 0.7240 - loss: 0.7973
# Epoch 9/10
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 41s 14ms/step - accuracy: 0.7364 - loss: 0.7568
# Epoch 10/10
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 22s 14ms/step - accuracy: 0.7507 - loss: 0.7151

# %% [markdown]
#  Evaluate Model

# %%
model.evaluate(x_test,y_test)
# Out:
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - accuracy: 0.6423 - loss: 1.0670
# [1.0669645071029663, 0.642300009727478]

# %%
model.evaluate(x_train, y_train)
# Out:
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 8s 5ms/step - accuracy: 0.7773 - loss: 0.6437
# [0.643661618232727, 0.7772799730300903]

# %% [markdown]
# Predictions

# %%
prediction = model.predict(x_test)
# Out:
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step

# %%
import numpy as np
print(np.argmax(prediction[1]))
# Out:
# 8

# %%
print(y_test[1])
# Out:
# [8]

# %% [markdown]
# In this project, I built a CNN model using TensorFlow and Keras on the CIFAR-10 dataset.
#
# The model was trained to classify color images like cats, dogs, ships, and airplanes.
#
# I learned:
# - how CNN works
# - image classification workflow
# - training and testing process
# - prediction probabilities
# - overfitting basics
#
# Final test accuracy: 64%
